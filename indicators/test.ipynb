# %%
import paca_sma as ind

# %%
d = ind.paca_20daybars(feed="iex", symbol="UNH")

# %%
import vectorbt as vbt
import vectorbt as vbt

# %%
d = ind.paca_20daybars(feed="iex", symbol="SPY")

# %%
start = '2019-03-01 UTC'  # crypto is in UTC
end = '2019-09-01 UTC'
cols = ['Open', 'High', 'Low', 'Close', 'Volume']
ohlcv = vbt.YFData.download("UNH", start=start, end=end).get(cols)
# Out:
# /tmp/ipykernel_224144/1423404692.py:4: DeprecationWarning: Parsing dates involving a day of month without a year specified is ambiguious
# and fails to parse leap day. The default behavior will change in Python 3.15
# to either always raise an exception or to use a different default year (TBD).
# To avoid trouble, add a specific year to the input & format.
# See https://github.com/python/cpython/issues/70647.
#   ohlcv = vbt.YFData.download("UNH", start=start, end=end).get(cols)

# %%
ohlcv.vbt.ohlcv.plot()
# Out:
# FigureWidget({
#     'data': [{'close': array([224.90571594, 215.65002441, 220.59306335, 218.43676758, 216.27131653,
#                               217.63793945, 223.0125885 , 225.51654053, 231.35896301, 232.29454041,
#                               230.5793457 , 233.88122559, 235.83479309, 229.75386047, 231.14804077,
#                               226.62625122, 226.41534424, 223.23274231, 221.69187927, 222.16876221,
#                               226.78222656, 225.20466614, 224.16825867, 225.47981262, 226.901474  ,
#                               228.17636108, 228.14883423, 228.1855011 , 225.65411377, 215.92279053,
#                               204.73320007, 211.13513184, 202.66038513, 198.88156128, 203.38494873,
#                               208.30101013, 211.48362732, 211.27268982, 211.67623901, 217.37193298,
#                               217.78469849, 213.7674408 , 212.74014282, 213.19877625, 212.74014282,
# ...
